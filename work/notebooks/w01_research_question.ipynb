# %% [markdown]
# <a href="https://colab.research.google.com/github/muska123-web/FlyRank-AI-Internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/muska123-web/FlyRank-AI-Internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# !git clone https://github.com/muska123-web/FlyRank-AI-Internship.git
# Out:
# Cloning into 'FlyRank-AI-Internship'...
# remote: Enumerating objects: 119, done.
# remote: Counting objects: 100% (119/119), done.
# remote: Compressing objects: 100% (76/76), done.
# remote: Total 119 (delta 35), reused 91 (delta 27), pack-reused 0 (from 0)
# Receiving objects: 100% (119/119), 1.84 MiB | 7.71 MiB/s, done.
# Resolving deltas: 100% (35/35), done.

# %%
import os

os.chdir("/content/FlyRank-AI-Internship")
print(os.getcwd())
# Out:
# /content/FlyRank-AI-Internship

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("lane selected : AI referral oppurtunity")
# Out:
# lane selected : AI referral oppurtunity

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# Decision :
# what decision will someone make to use my model.
#
# Action:
# what will the company do after getting the specific recommendations from the model.
#
# Cost of a wrong call:
# the company can suffer waste of resources and time ,also overlooking the pages that could get more traffic

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %%
import os

print(os.path.exists("data/raw/content_refresh_anonymized.csv"))
# Out:
# True

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Total pages:", len(df))
print("Average CTR:", round(df["ctr"].mean(), 3))
print("Median content age (days):", int(df["content_age_days"].median()))
# Out:
# Total pages: 30000
# Average CTR: 0.511
# Median content age (days): 236

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# ## Careful Words
#
# This project aims to identify patterns that may be associated with AI referral opportunities and provide decision support for content teams. The analysis may help prioritize webpages that appear more likely to attract AI-generated traffic based on the available data. Any recommendations will be based on observed relationships in the dataset rather than certainty.
#
# This project cannot prove why AI assistants choose specific webpages or predict exactly how ChatGPT, Gemini, Claude, or other AI systems rank or reference content. The findings will not establish cause-and-effect relationships or guarantee future AI referral traffic. They should be interpreted as evidence-based recommendations rather than definitive conclusions.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
